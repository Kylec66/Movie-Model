# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import ssl
from sqlalchemy import create_engine, inspect

# %%
movie_data = "../Resources/movies.csv"

movies_df = pd.read_csv(movie_data)

movies_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-02f5a51c591c> in <module>
#       1 movie_data = "../Resources/movies.csv"
#       2
# ----> 3 movies_df = pd.read_csv(movie_data)
#       4
#       5 movies_df
#
# ...

# %%
# Cleaned Dataset

movies_cleaned_df = movies_df.dropna()

movies_cleaned_df['votes'] = movies_cleaned_df['votes'].astype(int)
movies_cleaned_df['budget'] = movies_cleaned_df['budget'].astype(int)
movies_cleaned_df['gross'] = movies_cleaned_df['gross'].astype(int)
movies_cleaned_df['runtime'] = movies_cleaned_df['runtime'].astype(int)

movies_cleaned_df
# Out:
# <ipython-input-23-1094f5a483e2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_cleaned_df['votes'] = movies_cleaned_df['votes'].astype(int)
# <ipython-input-23-1094f5a483e2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_cleaned_df['budget'] = movies_cleaned_df['budget'].astype(int)
# <ipython-input-23-1094f5a483e2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
movies_cleaned_df.to_csv('movies_cleaned.csv', index = False)

# %%
# Model Dataset

movies_model_df = movies_cleaned_df.drop(columns=['name','released','votes','year','country', 'director', 'rating'])

movies_model_df
# Out:
#           genre  score                   writer               star     budget  \
# 0         Drama    8.4             Stephen King     Jack Nicholson   19000000
# 1     Adventure    5.8  Henry De Vere Stacpoole     Brooke Shields    4500000
# 2        Action    8.7           Leigh Brackett        Mark Hamill   18000000
# 3        Comedy    7.7             Jim Abrahams        Robert Hays    3500000
# 4        Comedy    7.3       Brian Doyle-Murray        Chevy Chase    6000000
# ...         ...    ...                      ...                ...        ...
# 7648     Action    6.6              Peter Craig         Will Smith   90000000
# 7649     Action    6.5                Pat Casey       Ben Schwartz   85000000
# 7650  Adventure    5.6           Stephen Gaghan  Robert Downey Jr.  175000000
# 7651  Adventure    6.8            Michael Green      Harrison Ford  135000000
# 7652     Action    6.8                  Hu Guan    Zhi-zhong Huang   80000000
#
# ...

# %%
movies_model_df.to_csv('movies_model.csv', index = False)

# %%
#create sqlite database and connect to it
database_path = "movies_model.sqlite"
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
# store dataframes into database
movies_model_df.to_sql('movies_model', conn, if_exists='replace')

# %%
# view tables in database
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['movies_model', 'stadiums']

# %%
#close database connection
conn.close()
